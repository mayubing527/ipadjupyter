# %%
from PIL import Image
import numpy as np

# %%
photo=Image.open('tower.jpg')
photo=photo.convert('L')

# %%
Im=np.array(photo)
Im0=np.gradient(Im)[0]
Im0=np.abs(Im0).astype('uint8')
Im0=Im0*(Im0>10)
Im0=255-Im0
Im0=Im0*(Im0>10)
Image.fromarray(Im0)
# Out:
# <PIL.Image.Image image mode=L size=3968x2976 at 0x2108619FEC8>
